# %%
import os
import pandas as pd
import librosa
import glob 
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
# from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix
from keras import regularizers
from scipy import signal
# Out:
# 2024-04-30 19:02:28.562046: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-30 19:02:28.634702: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-30 19:02:28.927766: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-30 19:02:30.025663: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
dir_list = os.listdir('data/')
dir_list.sort()
print (dir_list)
# Out:
# ['Actor_01', 'Actor_02', 'Actor_03', 'Actor_04', 'Actor_05', 'Actor_06', 'Actor_07', 'Actor_08', 'Actor_09', 'Actor_10', 'Actor_11', 'Actor_12', 'Actor_13', 'Actor_14', 'Actor_15', 'Actor_16', 'Actor_17', 'Actor_18', 'Actor_19', 'Actor_20', 'Actor_21', 'Actor_22', 'Actor_23', 'Actor_24']

# %%
data_df = pd.DataFrame(columns=['path', 'source', 'actor', 'gender',
                                'intensity', 'statement', 'repetition', 'emotion'])
count = 0
for i in dir_list:
    file_list = os.listdir('data/' + i)
    for f in file_list:
        nm = f.split('.')[0].split('-')
        path = 'data/' + i + '/' + f
        src = int(nm[1])
        actor = int(nm[-1])
        emotion = int(nm[2])
        
        if int(actor)%2 == 0:
            gender = "female"
        else:
            gender = "male"
        
        if nm[3] == '01':
            intensity = 0
        else:
            intensity = 1
        
        if nm[4] == '01':
            statement = 0
        else:
            statement = 1
        
        if nm[5] == '01':
            repeat = 0
        else:
            repeat = 1
            
        data_df.loc[count] = [path, src, actor, gender, intensity, statement, repeat, emotion]
        count += 1

# %%
data_df
# Out:
#                                         path  source  actor  gender  \
# 0     data/Actor_01/03-01-06-02-01-02-01.wav       1      1    male
# 1     data/Actor_01/03-01-08-02-01-02-01.wav       1      1    male
# 2     data/Actor_01/03-01-03-02-01-02-01.wav       1      1    male
# 3     data/Actor_01/03-01-06-01-01-02-01.wav       1      1    male
# 4     data/Actor_01/03-01-01-01-01-02-01.wav       1      1    male
# ...                                      ...     ...    ...     ...
# 1435  data/Actor_24/03-01-01-01-02-02-24.wav       1     24  female
# 1436  data/Actor_24/03-01-05-02-01-01-24.wav       1     24  female
# 1437  data/Actor_24/03-01-02-02-02-02-24.wav       1     24  female
# 1438  data/Actor_24/03-01-07-01-02-01-24.wav       1     24  female
# 1439  data/Actor_24/03-01-01-01-01-02-24.wav       1     24  female
#
#       intensity  statement  repetition  emotion
# 0             1          0           1        6
# 1             1          0           1        8
# 2             1          0           1        3
# 3             0          0           1        6
# 4             0          0           1        1
# ...         ...        ...         ...      ...
# 1435          0          1           1        1
# 1436          1          0           0        5
# 1437          1          1           1        2
# 1438          0          1           0        7
# 1439          0          0           1        1
#
# [1440 rows x 8 columns]

# %%
filename = data_df.path[1021]
print (filename)

samples, sample_rate = librosa.load(filename)
sample_rate, samples
# Out:
# data/Actor_18/03-01-08-01-01-02-18.wav
# (22050,
#  array([-5.972090e-08,  3.264942e-08, -8.642701e-09, ...,  0.000000e+00,
#          0.000000e+00,  0.000000e+00], dtype=float32))

# %%
len(samples), sample_rate
# Out:
# (77253, 22050)

# %%
def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %%
sample_rate/ len(samples)
# Out:
# 0.285425808706458

# %%
freqs, times, spectrogram = log_specgram(samples, sample_rate)

fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + filename)
ax1.set_ylabel('Amplitude')
librosa.display.waveshow(samples, sr=sample_rate)

ax2 = fig.add_subplot(212)
ax2.imshow(spectrogram.T, aspect='auto', origin='lower', 
           extent=[times.min(), times.max(), freqs.min(), freqs.max()])
ax2.set_yticks(freqs[::16])
ax2.set_xticks(times[::16])
ax2.set_title('Spectrogram of ' + filename)
ax2.set_ylabel('Freqs in Hz')
ax2.set_xlabel('Seconds')
# Out:
# Text(0.5, 0, 'Seconds')

# %%
# import os
# import librosa
# import librosa.display
# import matplotlib.pyplot as plt

# # Function to generate spectrogram
# def generate_spectrogram(audio_path, output_path, emotion):
#     # Load audio file
#     y, sr = librosa.load(audio_path, sr=None)
    
#     # Compute spectrogram
#     spectrogram = librosa.feature.melspectrogram(y=y, sr=sr)
    
#     # Convert to decibel scale
#     spectrogram_db = librosa.power_to_db(spectrogram, ref=np.max)
    
#     # Plot spectrogram
#     plt.figure(figsize=(10, 4))
#     librosa.display.specshow(spectrogram_db, sr=sr, x_axis='time', y_axis='mel')
#     plt.colorbar(format='%+2.0f dB')
#     plt.title('Mel Spectrogram - Emotion: {}'.format(emotion))
#     plt.tight_layout()
    
#     # Save spectrogram as image
#     output_folder = os.path.join(output_path, str(emotion))
#     if not os.path.exists(output_folder):
#         os.makedirs(output_folder)
#     plt.savefig(os.path.join(output_folder, '{}.png'.format(os.path.basename(audio_path).split('.')[0])))
#     plt.close()

# # Path to the RAVDESS dataset
# dataset_path = 'data/'

# # Output path to save spectrograms
# output_path = 'VGG_Spectograms/'

# # Iterate through actor folders
# for actor_folder in os.listdir(dataset_path):
#     actor_path = os.path.join(dataset_path, actor_folder)
#     if os.path.isdir(actor_path):
#         # Iterate through audio files in actor folder
#         for audio_file in os.listdir(actor_path):
#             if audio_file.endswith('.wav'):
#                 audio_path = os.path.join(actor_path, audio_file)
#                 # Extract emotion label from file name
#                 emotion = int(audio_file.split('-')[2])
#                 # Generate spectrogram
#                 generate_spectrogram(audio_path, output_path, emotion)

# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

input_shape = (224, 224, 3)
num_classes = 8
batch_size = 32
epochs = 20
data_dir = 'VGG_Spectograms/'

datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2)  # Splitting 80% for training, 20% for testing

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training', 
    seed=42,
    shuffle=True)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation', 
    seed=42,
    shuffle=True)

assert train_generator.class_indices == validation_generator.class_indices

X_train, X_test, y_train, y_test = train_test_split(
    np.zeros((len(train_generator.filenames), input_shape[0], input_shape[1], input_shape[2])),
    train_generator.labels,
    test_size=0.2,  
    random_state=42,
    stratify=train_generator.labels)
# Out:
# Found 1155 images belonging to 9 classes.
# Found 285 images belonging to 9 classes.

# %%
import os
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

input_shape = (224, 224, 3)
num_classes = 9
batch_size = 32
epochs = 100
data_dir = 'VGG_Spectograms/'

datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2)  # Splitting 80% for training, 20% for testing

train_generator = datagen.flow_from_directory(
    data_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',  
    seed=42,
    shuffle=True)

validation_generator = datagen.flow_from_directory(
    data_dir,
    target_size=input_shape[:2],
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    seed=42,
    shuffle=True)

assert train_generator.class_indices == validation_generator.class_indices

base_model = VGG16(weights='imagenet', include_top=False, input_shape=input_shape)

for layer in base_model.layers:
    layer.trainable = False

model = Sequential([
    base_model,
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.5),
    Dense(num_classes, activation='softmax')
])

model.compile(optimizer=Adam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

model_checkpoint = ModelCheckpoint(filepath='best_model.keras', 
                                   monitor='val_accuracy', 
                                   save_best_only=True, 
                                   mode='max', 
                                   verbose=1)

history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size,
    callbacks=[model_checkpoint])

best_model = load_model('best_model.keras')

loss, accuracy = best_model.evaluate(validation_generator)
print("Best Validation Accuracy:", accuracy)
# Out:
# Found 1155 images belonging to 9 classes.
# Found 285 images belonging to 9 classes.
# Epoch 1/100
# /home/karthik/anaconda3/lib/python3.11/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.1370 - loss: 6.1685
# Epoch 1: val_accuracy improved from -inf to 0.24609, saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 130s 3s/step - accuracy: 0.1375 - loss: 6.1133 - val_accuracy: 0.2461 - val_loss: 2.0031
# Epoch 2/100
#  1/36 ━━━━━━━━━━━━━━━━━━━━ 1:26 2s/step - accuracy: 0.2188 - loss: 2.0172
# 2024-04-30 19:04:50.055059: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# /home/karthik/anaconda3/lib/python3.11/contextlib.py:155: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# Epoch 2: val_accuracy did not improve from 0.24609
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.2188 - loss: 2.0172 - val_accuracy: 0.2414 - val_loss: 1.9620
# Epoch 3/100
# 2024-04-30 19:04:52.223918: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.2131 - loss: 2.0095
# Epoch 3: val_accuracy improved from 0.24609 to 0.28516, saving model to best_model.keras
# 36/36 ━━━━━━━━━━━━━━━━━━━━
val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 100ms/step - accuracy: 0.3438 - loss: 1.6160 - val_accuracy: 0.4828 - val_loss: 1.4605
# Epoch 89/100
# 2024-04-30 20:44:50.433868: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4122 - loss: 1.5113
# Epoch 89: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 168s 5s/step - accuracy: 0.4122 - loss: 1.5116 - val_accuracy: 0.3711 - val_loss: 1.6608
# Epoch 90/100
#  1/36 ━━━━━━━━━━━━━━━━━━━━ 1:52 3s/step - accuracy: 0.4688 - loss: 1.4945
# 2024-04-30 20:47:42.060664: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 2024-04-30 20:47:45.784755: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 90: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 10s 202ms/step - accuracy: 0.4688 - loss: 1.4945 - val_accuracy: 0.4138 - val_loss: 1.5544
# Epoch 91/100
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.3737 - loss: 1.5227
# Epoch 91: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 161s 4s/step - accuracy: 0.3744 - loss: 1.5222 - val_accuracy: 0.4453 - val_loss: 1.5319
# Epoch 92/100
#  1/36 ━━━━━━━━━━━━━━━━━━━━ 1:27 2s/step - accuracy: 0.4688 - loss: 1.2416
# 2024-04-30 20:50:32.133581: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 92: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 62ms/step - accuracy: 0.4688 - loss: 1.2416 - val_accuracy: 0.5172 - val_loss: 1.5283
# Epoch 93/100
# 2024-04-30 20:50:34.295733: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4104 - loss: 1.4863
# Epoch 93: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 134s 4s/step - accuracy: 0.4102 - loss: 1.4865 - val_accuracy: 0.4648 - val_loss: 1.4412
# Epoch 94/100
#  1/36 ━━━━━━━━━━━━━━━━━━━━ 13s 384ms/step - accuracy: 0.6667 - loss: 0.7554
# 2024-04-30 20:52:49.168642: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 94: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step - accuracy: 0.6667 - loss: 0.7554 - val_accuracy: 0.2759 - val_loss: 1.6284
# Epoch 95/100
# 2024-04-30 20:52:51.740020: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.3911 - loss: 1.4991
# Epoch 95: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 130s 4s/step - accuracy: 0.3912 - loss: 1.4990 - val_accuracy: 0.4102 - val_loss: 1.5317
# Epoch 96/100
#  1/36 ━━━━━━━━━━━━━━━━━━━━ 1:28 3s/step - accuracy: 0.5000 - loss: 1.2852
# 2024-04-30 20:55:04.189631: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 96: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 5s 63ms/step - accuracy: 0.5000 - loss: 1.2852 - val_accuracy: 0.4483 - val_loss: 1.6205
# Epoch 97/100
# 2024-04-30 20:55:06.377988: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4027 - loss: 1.5040
# Epoch 97: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 170s 5s/step - accuracy: 0.4032 - loss: 1.5031 - val_accuracy: 0.4531 - val_loss: 1.4466
# Epoch 98/100
#  1/36 ━━━━━━━━━━━━━━━━━━━━ 1:52 3s/step - accuracy: 0.3438 - loss: 1.2884
# 2024-04-30 20:57:59.486682: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 98: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - accuracy: 0.3438 - loss: 1.2884 - val_accuracy: 0.5172 - val_loss: 1.3551
# Epoch 99/100
# 2024-04-30 20:58:03.274926: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4s/step - accuracy: 0.4218 - loss: 1.4442
# Epoch 99: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 166s 5s/step - accuracy: 0.4213 - loss: 1.4453 - val_accuracy: 0.3477 - val_loss: 1.8615
# Epoch 100/100
#  1/36 ━━━━━━━━━━━━━━━━━━━━ 1:52 3s/step - accuracy: 0.3125 - loss: 1.7376
# 2024-04-30 21:00:52.783189: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# Epoch 100: val_accuracy did not improve from 0.55172
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 7s 109ms/step - accuracy: 0.3125 - loss: 1.7376 - val_accuracy: 0.3448 - val_loss: 1.8753
# 2024-04-30 21:00:56.598473: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 33s 4s/step - accuracy: 0.4768 - loss: 1.5125
# Best Validation Accuracy: 0.5017544031143188

# %%
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

img_path = 'VGG_Spectograms/7/03-01-07-01-01-01-01.png'  
img = image.load_img(img_path, target_size=input_shape[:2])
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  

img_array /= 255.0  

best_model = load_model('best_model.keras')

predictions = best_model.predict(img_array)

emotion_label = np.argmax(predictions)

print("Predicted Emotion Label:", emotion_label)

plt.imshow(img)
plt.axis('off')
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# Predicted Emotion Label: 7
